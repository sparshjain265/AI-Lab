# %%
import numpy as np
import random
import math
import matplotlib.pyplot as plt

# %%
t = 1000
eta = np.random.choice([-1, 1], t)
theta = np.zeros(t)
T = np.arange(1, t+1,1)
for i in range(t):
    theta[i] = sum(eta[0:i])

Tinv = []
for i in T:
    Tinv.append(1/i)

sqTinv = []
for i in Tinv:
    sqTinv.append(math.sqrt(i))

nsqTinv = []
for i in Tinv:
    nsqTinv.append(-1*math.sqrt(i))

# %%
theta = np.zeros(n.shape)
for i in range(t):
	theta[i] = sum(n[0:i])

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot(xs = n[:, 0], ys = n[:, 1], zs = T, label = "n")
ax.plot(xs = theta[:, 0], ys = theta[:, 1], zs = T, label = "theta")
